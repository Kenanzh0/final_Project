# %%
import numpy as np
import pandas as pd
import sqlalchemy
import pymysql

# %%
eng=sqlalchemy.create_engine('mysql+pymysql://root:123456@localhost/dataco')

# %%
df = pd.read_csv('owid-covid-data NEW.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390684 entries, 0 to 390683
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    390684 non-null  object
#  1   continent                                   371988 non-null  object
#  2   location                                    390684 non-null  object
#  3   date                                        390684 non-null  object
#  4   total_cases                                 351749 non-null  float64
#  5   new_cases                                   379668 non-null  float64
#  6   new_cases_smoothed                          378438 non-null  float64
#  7   total_deaths                                329441 non-null  float64
#  8   new_deaths                                  379991 non-null  float64
# ...

# %%
df = df[df.location != 'Israel']

# %%
df=df.drop(columns = ["cardiovasc_death_rate","total_cases_per_million","new_cases_per_million"
                    ,"new_cases_smoothed_per_million","total_deaths_per_million","new_deaths_per_million"
                    ,"new_deaths_smoothed_per_million","new_deaths_smoothed_per_million", 
                    "icu_patients_per_million","hosp_patients_per_million","weekly_icu_admissions","weekly_hosp_admissions",
                    "weekly_icu_admissions_per_million","weekly_hosp_admissions_per_million","total_tests_per_thousand",
                    "new_tests_per_thousand","new_tests_smoothed_per_thousand","total_boosters_per_hundred",
                    "total_vaccinations_per_hundred","aged_70_older","new_vaccinations_smoothed_per_million",
                    "new_people_vaccinated_smoothed_per_hundred","gdp_per_capita","hospital_beds_per_thousand",
                    "excess_mortality_cumulative_per_million","new_cases_smoothed","new_deaths_smoothed", 
                    "new_cases_smoothed_per_million","new_tests_smoothed","new_tests_smoothed_per_thousand",
                    "new_vaccinations_smoothed","new_vaccinations_smoothed_per_million","new_people_vaccinated_smoothed",     
                    "new_people_vaccinated_smoothed_per_hundred","tests_units","diabetes_prevalence","excess_mortality",
                    "excess_mortality_cumulative",
                    "excess_mortality_cumulative_absolute","stringency_index","positive_rate","total_boosters",
                    "new_vaccinations","median_age","extreme_poverty","handwashing_facilities","life_expectancy",
                    "human_development_index"])

# %%
df["nulls"]=df.isnull().sum(axis = 1)

# %%
df.isnull().sum(axis = 1).unique()
# Out:
# array([15, 14, 12,  9,  7, 11,  6, 10, 13,  8, 18, 17, 16,  4,  2,  5,  1,
#         0,  3, 19], dtype=int64)

# %%
df.isnull().sum(axis = 1).value_counts()
# Out:
# 11    74883
# 10    46142
# 13    38249
# 12    32103
# 15    28650
# 7     27143
# 14    23639
# 5     20418
# 9     16396
# 16    14686
# 2     12382
# 6     10767
# 8     10460
# 4      8680
# 17     8542
# 0      7114
# 3      4534
# 1      2680
# 19      876
# 18      792
# dtype: int64

# %%
df=df[df["nulls"] < 16]
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 390679      ZWE    Africa     Zimbabwe  2024-03-27     266359.0        0.0
# 390680      ZWE    Africa     Zimbabwe  2024-03-28     266359.0        0.0
# 390681      ZWE    Africa     Zimbabwe  2024-03-29     266359.0        0.0
# 390682      ZWE    Africa     Zimbabwe  2024-03-30     266359.0        0.0
# 390683      ZWE    Africa     Zimbabwe  2024-03-31     266359.0        0.0
#
# ...

# %%
df=df.drop("nulls",axis='columns')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364240 entries, 0 to 390683
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   iso_code                             364240 non-null  object
#  1   continent                            349796 non-null  object
#  2   location                             364240 non-null  object
#  3   date                                 364240 non-null  object
#  4   total_cases                          338638 non-null  float64
#  5   new_cases                            357343 non-null  float64
#  6   total_deaths                         324071 non-null  float64
#  7   new_deaths                           357668 non-null  float64
#  8   reproduction_rate                    183728 non-null  float64
#  9   icu_patients                         36122 non-null   float64
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  total_deaths     new_deaths  \
# count  3.386380e+05  3.573430e+05  3.240710e+05  357668.000000
# mean   7.665310e+06  8.766346e+03  9.001526e+04      72.239529
# std    4.507231e+07  2.452591e+05  4.612448e+05    1402.157248
# min    1.000000e+00  0.000000e+00  1.000000e+00       0.000000
# 25%    1.101600e+04  0.000000e+00  1.330000e+02       0.000000
# 50%    8.530600e+04  0.000000e+00  1.361000e+03       0.000000
# 75%    8.730680e+05  0.000000e+00  1.203100e+04       0.000000
# max    7.752518e+08  4.423623e+07  7.043660e+06  103719.000000
#
#        reproduction_rate  icu_patients  hosp_patients   total_tests  \
# count      183728.000000  36122.000000   36932.000000  7.844600e+04
# mean            0.910747    704.159598    4171.566338  2.115447e+07
# std             0.399702   2218.755067   10253.144795  8.457957e+07
# min            -0.070000      0.000000       0.000000  0.000000e+00
# ...

# %%
l=df['location'].nunique()
df_locations=pd.DataFrame([{'locations':l}])
df_locations
# Out:
#    locations
# 0        252

# %%
df_locations.to_sql('df_locations',eng,index =False)
# Out:
# 1

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_world = df[df.location == 'World']
df_world
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 384477  OWID_WRL       NaN    World  2020-01-05          2.0        2.0
# 384478  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 384479  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 384480  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 384481  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 386035  OWID_WRL       NaN    World  2024-04-11          NaN        NaN
# 386036  OWID_WRL       NaN    World  2024-04-12          NaN        NaN
# 386037  OWID_WRL       NaN    World  2024-04-13          NaN        NaN
# 386038  OWID_WRL       NaN    World  2024-04-14          NaN        NaN
# 386039  OWID_WRL       NaN    World  2024-04-15          NaN        NaN
#
#         total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# ...

# %%
df_world.to_sql('df_world',eng,index =False)
# Out:
# 1563

# %%
pd.read_sql('df_world',eng)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 0     OWID_WRL      None    World  2020-01-05          2.0        2.0
# 1     OWID_WRL      None    World  2020-01-06          2.0        0.0
# 2     OWID_WRL      None    World  2020-01-07          2.0        0.0
# 3     OWID_WRL      None    World  2020-01-08          2.0        0.0
# 4     OWID_WRL      None    World  2020-01-09          2.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 1558  OWID_WRL      None    World  2024-04-11          NaN        NaN
# 1559  OWID_WRL      None    World  2024-04-12          NaN        NaN
# 1560  OWID_WRL      None    World  2024-04-13          NaN        NaN
# 1561  OWID_WRL      None    World  2024-04-14          NaN        NaN
# 1562  OWID_WRL      None    World  2024-04-15          NaN        NaN
#
#       total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# ...

# %%
df_world_max_new_death=df_world[df_world['new_deaths'] == df_world['new_deaths'].max()][['date','new_deaths']]
df_world_max_new_death
# Out:
#               date  new_deaths
# 384862  2021-01-24    103719.0

# %%
df_world_max_new_death.to_sql('df_world_max_new_death',eng,index =False)
# Out:
# 1

# %%
pd.read_sql('df_world_max_new_death',eng)
# Out:
#          date  new_deaths
# 0  2021-01-24    103719.0

# %%
df_world_recent = df_world[df_world['new_cases'] == df_world.new_cases.max()][["date","total_cases","new_cases","new_deaths","total_deaths"]]
df_world_recent
# Out:
#               date  total_cases   new_cases  new_deaths  total_deaths
# 385562  2022-12-25  704631589.0  44236227.0     20316.0     6695696.0

# %%
df_world_recent.to_sql('df_world_recent',eng,index =False)
# Out:
# 1

# %%
pd.read_sql('df_world_recent',eng)
# Out:
#          date  total_cases   new_cases  new_deaths  total_deaths
# 0  2022-12-25  704631589.0  44236227.0     20316.0     6695696.0

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum().reset_index().sort_values("date",ascending=True).reset_index(drop=True)
df_world_over_time
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-01-05          2.0        2.0           3.0         3.0
# 1     2020-01-06          2.0        0.0           3.0         0.0
# 2     2020-01-07          2.0        0.0           3.0         0.0
# 3     2020-01-08          2.0        0.0           3.0         0.0
# 4     2020-01-09          2.0        0.0           3.0         0.0
# ...          ...          ...        ...           ...         ...
# 1558  2024-04-11          0.0        0.0           0.0         0.0
# 1559  2024-04-12          0.0        0.0           0.0         0.0
# 1560  2024-04-13          0.0        0.0           0.0         0.0
# 1561  2024-04-14          0.0        0.0           0.0         0.0
# 1562  2024-04-15          0.0        0.0           0.0         0.0
#
# [1563 rows x 5 columns]

# %%
df_world_over_time.to_sql('df_world_over_time',eng,index =False)
pd.read_sql('df_world_over_time',eng)
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-01-05          2.0        2.0           3.0         3.0
# 1     2020-01-06          2.0        0.0           3.0         0.0
# 2     2020-01-07          2.0        0.0           3.0         0.0
# 3     2020-01-08          2.0        0.0           3.0         0.0
# 4     2020-01-09          2.0        0.0           3.0         0.0
# ...          ...          ...        ...           ...         ...
# 1558  2024-04-11          0.0        0.0           0.0         0.0
# 1559  2024-04-12          0.0        0.0           0.0         0.0
# 1560  2024-04-13          0.0        0.0           0.0         0.0
# 1561  2024-04-14          0.0        0.0           0.0         0.0
# 1562  2024-04-15          0.0        0.0           0.0         0.0
#
# [1563 rows x 5 columns]

# %%
df_world['total_cases'].max()
# Out:
# 775251765.0

# %%
t_c=df_world['total_cases'].max()
df_total_cases=pd.DataFrame([{'total_cases':t_c}])
df_total_cases
# Out:
#    total_cases
# 0  775251765.0

# %%
df_total_cases.to_sql('df_total_cases',eng,index =False)
pd.read_sql('df_total_cases',eng)
# Out:
#    total_cases
# 0  775251765.0

# %%
df_world_ratio = df_world['total_cases'].max() / df_world['population'].max()
df_world_ratio
# Out:
# 0.0972089725046861

# %%
df_world_ratio=pd.DataFrame([{'world_ratio':df_world_ratio}])
df_world_ratio
# Out:
#    world_ratio
# 0     0.097209

# %%
df_world_ratio.to_sql('df_world_ratio',eng,index =False)
pd.read_sql('df_world_ratio',eng)
# Out:
#    world_ratio
# 0     0.097209

# %%
df_syria = df[df['location'] == 'Syria']
df_syria
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 338657      SYR      Asia    Syria  2020-04-05         16.0       11.0
# 338658      SYR      Asia    Syria  2020-04-06         16.0        0.0
# 338659      SYR      Asia    Syria  2020-04-07         16.0        0.0
# 338660      SYR      Asia    Syria  2020-04-08         16.0        0.0
# 338661      SYR      Asia    Syria  2020-04-09         16.0        0.0
# ...         ...       ...      ...         ...          ...        ...
# 340109      SYR      Asia    Syria  2024-03-27      57423.0        0.0
# 340110      SYR      Asia    Syria  2024-03-28      57423.0        0.0
# 340111      SYR      Asia    Syria  2024-03-29      57423.0        0.0
# 340112      SYR      Asia    Syria  2024-03-30      57423.0        0.0
# 340113      SYR      Asia    Syria  2024-03-31      57423.0        0.0
#
#         total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# ...

# %%
df_syria2=df_syria[['date','total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]]
df_syria2
# Out:
#               date  total_cases  new_cases  total_deaths  new_deaths
# 338657  2020-04-05         16.0       11.0           2.0         2.0
# 338658  2020-04-06         16.0        0.0           2.0         0.0
# 338659  2020-04-07         16.0        0.0           2.0         0.0
# 338660  2020-04-08         16.0        0.0           2.0         0.0
# 338661  2020-04-09         16.0        0.0           2.0         0.0
# ...            ...          ...        ...           ...         ...
# 340109  2024-03-27      57423.0        0.0        3163.0         0.0
# 340110  2024-03-28      57423.0        0.0        3163.0         0.0
# 340111  2024-03-29      57423.0        0.0        3163.0         0.0
# 340112  2024-03-30      57423.0        0.0        3163.0         0.0
# 340113  2024-03-31      57423.0        0.0        3163.0         0.0
#
# [1457 rows x 5 columns]

# %%
df_syria2.to_sql('df_syria2',eng,index =False)
pd.read_sql('df_syria2',eng)
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-04-05         16.0       11.0           2.0         2.0
# 1     2020-04-06         16.0        0.0           2.0         0.0
# 2     2020-04-07         16.0        0.0           2.0         0.0
# 3     2020-04-08         16.0        0.0           2.0         0.0
# 4     2020-04-09         16.0        0.0           2.0         0.0
# ...          ...          ...        ...           ...         ...
# 1452  2024-03-27      57423.0        0.0        3163.0         0.0
# 1453  2024-03-28      57423.0        0.0        3163.0         0.0
# 1454  2024-03-29      57423.0        0.0        3163.0         0.0
# 1455  2024-03-30      57423.0        0.0        3163.0         0.0
# 1456  2024-03-31      57423.0        0.0        3163.0         0.0
#
# [1457 rows x 5 columns]

# %%
df_syria_recent = df_syria[df_syria['date'] == df_syria.date.max()]
df_syria_recent
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 340113      SYR      Asia    Syria  2024-03-31      57423.0        0.0
#
#         total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 340113        3163.0         0.0                NaN           NaN  ...
#
#         total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 340113                 NaN                NaN                      NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 340113                            NaN                                  NaN
#
#         population_density  aged_65_older  female_smokers  male_smokers  \
# 340113                 NaN            NaN             NaN           NaN
#
#         population
# 340113  22125242.0
#
# [1 rows x 24 columns]

# %%
df_syria_recent.to_sql('df_syria_recent',eng,index =False)
pd.read_sql('df_syria_recent',eng)
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      SYR      Asia    Syria  2024-03-31      57423.0        0.0
#
#    total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0        3163.0         0.0                NaN           NaN  ...
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            NaN                                  NaN
#
#    population_density  aged_65_older  female_smokers  male_smokers  population
# 0                 NaN            NaN             NaN           NaN  22125242.0
#
# [1 rows x 24 columns]

# %%
df_syria_recent2=df_syria_recent[['date','total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]]
df_syria_recent2
# Out:
#               date  total_cases  new_cases  total_deaths  new_deaths
# 340113  2024-03-31      57423.0        0.0        3163.0         0.0

# %%
df_syria_recent2.to_sql('df_syria_recent2',eng,index =False)
pd.read_sql('df_syria_recent2',eng)
# Out:
#          date  total_cases  new_cases  total_deaths  new_deaths
# 0  2024-03-31      57423.0        0.0        3163.0         0.0

# %%
df_syria4=df_syria[df_syria['new_deaths'] == df_syria['new_deaths'].max()]['date'].reset_index().reset_index(drop=True).drop("index",axis='columns')
df_syria4
# Out:
#          date
# 0  2021-10-24

# %%
df_syria_max=df_syria[['total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]].max()
df_syria_max=pd.DataFrame([df_syria_max])
df_syria_max
# Out:
#    total_cases  new_cases  total_deaths  new_deaths
# 0      57423.0     2517.0        3163.0       101.0

# %%
df_syria_max.to_sql('df_syria_max',eng,index =False)
pd.read_sql('df_syria_max',eng)
# Out:
#    total_cases  new_cases  total_deaths  new_deaths
# 0      57423.0     2517.0        3163.0       101.0

# %%
l=df_syria['new_cases'].mean()
l
# Out:
# 39.40837336993823

# %%
df_new_cases_syria_mean=pd.DataFrame([{'new_cases':l}])
df_new_cases_syria_mean
# Out:
#    new_cases
# 0  39.408373

# %%
df_new_cases_syria_mean.to_sql('df_new_cases_syria_mean',eng,index =False)
pd.read_sql('df_new_cases_syria_mean',eng)
# Out:
#    new_cases
# 0  39.408373

# %%
df_syria_mod = df_syria[['date', 'new_cases']]
df_syria_mod
# Out:
#               date  new_cases
# 338657  2020-04-05       11.0
# 338658  2020-04-06        0.0
# 338659  2020-04-07        0.0
# 338660  2020-04-08        0.0
# 338661  2020-04-09        0.0
# ...            ...        ...
# 340109  2024-03-27        0.0
# 340110  2024-03-28        0.0
# 340111  2024-03-29        0.0
# 340112  2024-03-30        0.0
# 340113  2024-03-31        0.0
#
# [1457 rows x 2 columns]

# %%
df_syria_mod.to_sql('df_syria_mod',eng,index =False)
pd.read_sql('df_syria_mod',eng)
# Out:
#             date  new_cases
# 0     2020-04-05       11.0
# 1     2020-04-06        0.0
# 2     2020-04-07        0.0
# 3     2020-04-08        0.0
# 4     2020-04-09        0.0
# ...          ...        ...
# 1452  2024-03-27        0.0
# 1453  2024-03-28        0.0
# 1454  2024-03-29        0.0
# 1455  2024-03-30        0.0
# 1456  2024-03-31        0.0
#
# [1457 rows x 2 columns]

# %%
df_syria_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1457 entries, 338657 to 340113
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1457 non-null   object
#  1   new_cases  1457 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 34.1+ KB

# %%
df_no_world = df [~df["location"].isin(['Africa','World','Asia','Europe','Upper middle income','European Union',
                                        'North America','United States','High income','Lower middle income','South America'])]
df_no_world
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 390679      ZWE    Africa     Zimbabwe  2024-03-27     266359.0        0.0
# 390680      ZWE    Africa     Zimbabwe  2024-03-28     266359.0        0.0
# 390681      ZWE    Africa     Zimbabwe  2024-03-29     266359.0        0.0
# 390682      ZWE    Africa     Zimbabwe  2024-03-30     266359.0        0.0
# 390683      ZWE    Africa     Zimbabwe  2024-03-31     266359.0        0.0
#
# ...

# %%
df_no_world.to_sql('df_no_world',eng,index =False)
pd.read_sql('df_no_world',eng)
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 350413      ZWE    Africa     Zimbabwe  2024-03-27     266359.0        0.0
# 350414      ZWE    Africa     Zimbabwe  2024-03-28     266359.0        0.0
# 350415      ZWE    Africa     Zimbabwe  2024-03-29     266359.0        0.0
# 350416      ZWE    Africa     Zimbabwe  2024-03-30     266359.0        0.0
# 350417      ZWE    Africa     Zimbabwe  2024-03-31     266359.0        0.0
#
# ...

# %%
l=df_no_world['location'].nunique()
l
# Out:
# 241

# %%
df_no_world['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'England',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364240 entries, 0 to 390683
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   iso_code                             364240 non-null  object
#  1   continent                            349796 non-null  object
#  2   location                             364240 non-null  object
#  3   date                                 364240 non-null  object
#  4   total_cases                          338638 non-null  float64
#  5   new_cases                            357343 non-null  float64
#  6   total_deaths                         324071 non-null  float64
#  7   new_deaths                           357668 non-null  float64
#  8   reproduction_rate                    183728 non-null  float64
#  9   icu_patients                         36122 non-null   float64
# ...

# %%
m=df_world['male_smokers'].unique()
m_s=m[0]
m_s
# Out:
# 34.635

# %%
df_male_smokers=pd.DataFrame([{'male_smokers':m_s}])
df_male_smokers
# Out:
#    male_smokers
# 0        34.635

# %%
df_male_smokers.to_sql('df_male_smokers',eng,index =False)
pd.read_sql('df_male_smokers',eng)
# Out:
#    male_smokers
# 0        34.635

# %%
f=df_world['female_smokers'].unique()
f_s=f[0]
f_s
# Out:
# 6.434

# %%
df_female_smokers=pd.DataFrame([{'female_smokers':f_s}])
df_female_smokers
# Out:
#    female_smokers
# 0           6.434

# %%
df_female_smokers.to_sql('df_female_smokers',eng,index =False)
pd.read_sql('df_female_smokers',eng)
# Out:
#    female_smokers
# 0           6.434

# %%
a65o=df_world['aged_65_older'].unique()
aged_65_older=a65o[0]
aged_65_older
# Out:
# 8.696

# %%
df_aged_65_older=pd.DataFrame([{'aged_65_older':aged_65_older}])
df_aged_65_older
# Out:
#    aged_65_older
# 0          8.696

# %%
df_aged_65_older.to_sql('df_aged_65_older',eng,index =False)
pd.read_sql('df_aged_65_older',eng)
# Out:
#    aged_65_older
# 0          8.696

# %%
df_world_reproduction_rate1=df_world[['date','reproduction_rate']]
df_world_reproduction_rate=df_world_reproduction_rate1.dropna()
df_world_reproduction_rate
# Out:
#               date  reproduction_rate
# 384495  2020-01-23               3.15
# 384496  2020-01-24               3.32
# 384497  2020-01-25               3.48
# 384498  2020-01-26               3.55
# 384499  2020-01-27               3.59
# ...            ...                ...
# 385566  2022-12-29               0.94
# 385567  2022-12-30               0.94
# 385568  2022-12-31               0.95
# 385569  2023-01-01               0.95
# 385570  2023-01-02               0.94
#
# [1076 rows x 2 columns]

# %%
df_world_reproduction_rate.to_sql('df_world_reproduction_rate',eng,index =False)
pd.read_sql('df_world_reproduction_rate',eng)
# Out:
#             date  reproduction_rate
# 0     2020-01-23               3.15
# 1     2020-01-24               3.32
# 2     2020-01-25               3.48
# 3     2020-01-26               3.55
# 4     2020-01-27               3.59
# ...          ...                ...
# 1071  2022-12-29               0.94
# 1072  2022-12-30               0.94
# 1073  2022-12-31               0.95
# 1074  2023-01-01               0.95
# 1075  2023-01-02               0.94
#
# [1076 rows x 2 columns]

# %%
df_icu_hosp_patients=df_no_world[['date','location','total_cases','hosp_patients','icu_patients']].dropna()
df_icu_hosp_patients
# Out:
#               date        location  total_cases  hosp_patients  icu_patients
# 20229   2020-03-31       Australia       3809.0          426.0          82.0
# 20230   2020-04-01       Australia       3809.0          441.0          86.0
# 20231   2020-04-02       Australia       3809.0          415.0          92.0
# 20232   2020-04-03       Australia       3809.0          457.0          93.0
# 20233   2020-04-04       Australia       3809.0          490.0          95.0
# ...            ...             ...          ...            ...           ...
# 367095  2022-05-18  United Kingdom   22195702.0         6763.0         188.0
# 367096  2022-05-19  United Kingdom   22195702.0         6618.0         191.0
# 367097  2022-05-20  United Kingdom   22195702.0         6407.0         194.0
# 367098  2022-05-21  United Kingdom   22195702.0         6190.0         184.0
# 367099  2022-05-22  United Kingdom   22247777.0         6137.0         175.0
#
# [26605 rows x 5 columns]

# %%
table_icu_hosp_patients_max=df_icu_hosp_patients.groupby('location')[['total_cases','hosp_patients','icu_patients',]].max().reset_index().sort_values("location",ascending=True).reset_index(drop=True)
table_icu_hosp_patients_max
# Out:
#           location  total_cases  hosp_patients  icu_patients
# 0        Australia   11679177.0         5571.0         424.0
# 1          Austria    6080775.0         4689.0         709.0
# 2          Belgium    4801652.0         7461.0        1474.0
# 3          Bolivia    1108648.0         2433.0         235.0
# 4         Bulgaria    1317573.0        10355.0         799.0
# 5           Canada    4785876.0        11489.0        1313.0
# 6           Cyprus     656904.0          301.0          57.0
# 7          Czechia    4758954.0         9552.0        1896.0
# 8          Denmark    3414007.0         1762.0         153.0
# 9          Estonia     600527.0          707.0          70.0
# 10         Finland    1429634.0         1089.0          83.0
# 11          France   38588428.0        33466.0        7019.0
# 12         Ireland    1725769.0         1610.0          92.0
# 13           Italy   26718988.0        38507.0        4068.0
# ...

# %%
table_icu_hosp_patients_max.to_sql('table_icu_hosp_patients_max',eng,index=False)
pd.read_sql('table_icu_hosp_patients_max' ,eng)
# Out:
#           location  total_cases  hosp_patients  icu_patients
# 0        Australia   11679177.0         5571.0         424.0
# 1          Austria    6080775.0         4689.0         709.0
# 2          Belgium    4801652.0         7461.0        1474.0
# 3          Bolivia    1108648.0         2433.0         235.0
# 4         Bulgaria    1317573.0        10355.0         799.0
# 5           Canada    4785876.0        11489.0        1313.0
# 6           Cyprus     656904.0          301.0          57.0
# 7          Czechia    4758954.0         9552.0        1896.0
# 8          Denmark    3414007.0         1762.0         153.0
# 9          Estonia     600527.0          707.0          70.0
# 10         Finland    1429634.0         1089.0          83.0
# 11          France   38588428.0        33466.0        7019.0
# 12         Ireland    1725769.0         1610.0          92.0
# 13           Italy   26718988.0        38507.0        4068.0
# ...

# %%
df_tests_per_case=df_no_world.groupby('location')[['total_cases','tests_per_case']].max()
df_tests_per_case
# Out:
#                    total_cases  tests_per_case
# location
# Afghanistan           232948.0           173.5
# Albania               334863.0          1067.6
# Algeria               272017.0             NaN
# American Samoa          8359.0             NaN
# Andorra                48015.0           156.5
# ...                        ...             ...
# Wales                      NaN             NaN
# Wallis and Futuna       3760.0             NaN
# Yemen                  11945.0           587.4
# Zambia                349558.0           545.5
# Zimbabwe              266359.0          1125.9
#
# [241 rows x 2 columns]

# %%
df_tests_per_case=df_tests_per_case.groupby('location')[['total_cases','tests_per_case']].max().reset_index().sort_values("location",ascending=True).reset_index(drop=True)
df_tests_per_case
# Out:
#               location  total_cases  tests_per_case
# 0          Afghanistan     232948.0           173.5
# 1              Albania     334863.0          1067.6
# 2              Algeria     272017.0             NaN
# 3       American Samoa       8359.0             NaN
# 4              Andorra      48015.0           156.5
# ..                 ...          ...             ...
# 236              Wales          NaN             NaN
# 237  Wallis and Futuna       3760.0             NaN
# 238              Yemen      11945.0           587.4
# 239             Zambia     349558.0           545.5
# 240           Zimbabwe     266359.0          1125.9
#
# [241 rows x 3 columns]

# %%
df_tests_per_case.to_sql('df_tests_per_case',eng,index=False)
pd.read_sql('df_tests_per_case' ,eng)
# Out:
#               location  total_cases  tests_per_case
# 0          Afghanistan     232948.0           173.5
# 1              Albania     334863.0          1067.6
# 2              Algeria     272017.0             NaN
# 3       American Samoa       8359.0             NaN
# 4              Andorra      48015.0           156.5
# ..                 ...          ...             ...
# 236              Wales          NaN             NaN
# 237  Wallis and Futuna       3760.0             NaN
# 238              Yemen      11945.0           587.4
# 239             Zambia     349558.0           545.5
# 240           Zimbabwe     266359.0          1125.9
#
# [241 rows x 3 columns]

# %%
df_no_world["people_vaccinated_per_hundred"].dropna()
# Out:
# 414        0.00
# 420        0.02
# 436        0.13
# 458        0.29
# 473        0.58
#           ...
# 390136    39.43
# 390137    39.43
# 390138    39.43
# 390140    39.44
# 390144    39.45
# Name: people_vaccinated_per_hundred, Length: 65728, dtype: float64

# %%
df_people_vaccinated =df_no_world.groupby('location')[["people_vaccinated_per_hundred"]].max().dropna()
df_people_vaccinated
# Out:
#                    people_vaccinated_per_hundred
# location
# Afghanistan                                45.95
# Albania                                    47.47
# Algeria                                    17.46
# Andorra                                    72.53
# Angola                                     46.43
# ...                                          ...
# Wales                                      81.77
# Wallis and Futuna                          61.66
# Yemen                                       3.12
# Zambia                                     58.51
# Zimbabwe                                   39.45
#
# [223 rows x 1 columns]

# %%
df_people_vaccinated.to_sql('df_people_vaccinated',eng,index=False)
pd.read_sql('df_people_vaccinated' ,eng)
# Out:
#      people_vaccinated_per_hundred
# 0                            45.95
# 1                            47.47
# 2                            17.46
# 3                            72.53
# 4                            46.43
# ..                             ...
# 218                          81.77
# 219                          61.66
# 220                           3.12
# 221                          58.51
# 222                          39.45
#
# [223 rows x 1 columns]

# %%
df_fully_people_vaccinated=df_world.groupby('location')[["people_fully_vaccinated_per_hundred","people_vaccinated_per_hundred"]].max().reset_index().sort_values("location",ascending=True).reset_index(drop=True)
df_fully_people_vaccinated
# Out:
#   location  people_fully_vaccinated_per_hundred  people_vaccinated_per_hundred
# 0    World                                64.91                           70.6

# %%
df_fully_people_vaccinated.to_sql('df_fully_people_vaccinated',eng,index=False)
pd.read_sql('df_fully_people_vaccinated' ,eng)
# Out:
#   location  people_fully_vaccinated_per_hundred  people_vaccinated_per_hundred
# 0    World                                64.91                           70.6

# %%
df_top5=df_no_world.groupby("location")[["total_cases","total_deaths"]].max().reset_index().sort_values("total_cases",ascending=False).reset_index(drop=True).head(5)
df_top5
# Out:
#   location  total_cases  total_deaths
# 0    China   99347448.0      122121.0
# 1    India   45034360.0      533552.0
# 2   France   38997490.0      168090.0
# 3  Germany   38437756.0      174979.0
# 4   Brazil   37519960.0      702116.0

# %%
df_top5.to_sql('df_top5',eng,index =False)
pd.read_sql('df_top5',eng)
# Out:
#   location  total_cases  total_deaths
# 0    China   99347448.0      122121.0
# 1    India   45034360.0      533552.0
# 2   France   38997490.0      168090.0
# 3  Germany   38437756.0      174979.0
# 4   Brazil   37519960.0      702116.0

# %%
df_jun_syria = df_syria[['date','new_cases']][(df_syria.date >= '2020-06-01') & (df_syria.date <= '2020-06-31')].reset_index(drop=True)
df_jun_syria
# Out:
#           date  new_cases
# 0   2020-06-01        0.0
# 1   2020-06-02        0.0
# 2   2020-06-03        0.0
# 3   2020-06-04        0.0
# 4   2020-06-05        0.0
# 5   2020-06-06        0.0
# 6   2020-06-07        3.0
# 7   2020-06-08        0.0
# 8   2020-06-09        0.0
# 9   2020-06-10        0.0
# 10  2020-06-11        0.0
# 11  2020-06-12        0.0
# 12  2020-06-13        0.0
# 13  2020-06-14       45.0
# 14  2020-06-15        0.0
# 15  2020-06-16        0.0
# 16  2020-06-17        0.0
# 17  2020-06-18        0.0
# 18  2020-06-19        0.0
# 19  2020-06-20        0.0
# 20  2020-06-21       28.0
# 21  2020-06-22        0.0
# 22  2020-06-23        0.0
# 23  2020-06-24        0.0
# 24  2020-06-25        0.0
# 25  2020-06-26        0.0
# 26  2020-06-27        0.0
# 27  2020-06-28       58.0
# 28  2020-06-29        0.0
# 29  2020-06-30        0.0

# %%
df_jun_syria.to_sql('df_jun_syria',eng,index=False)
pd.read_sql('df_jun_syria' ,eng)
# Out:
#           date  new_cases
# 0   2020-06-01        0.0
# 1   2020-06-02        0.0
# 2   2020-06-03        0.0
# 3   2020-06-04        0.0
# 4   2020-06-05        0.0
# 5   2020-06-06        0.0
# 6   2020-06-07        3.0
# 7   2020-06-08        0.0
# 8   2020-06-09        0.0
# 9   2020-06-10        0.0
# 10  2020-06-11        0.0
# 11  2020-06-12        0.0
# 12  2020-06-13        0.0
# 13  2020-06-14       45.0
# 14  2020-06-15        0.0
# 15  2020-06-16        0.0
# 16  2020-06-17        0.0
# 17  2020-06-18        0.0
# 18  2020-06-19        0.0
# 19  2020-06-20        0.0
# 20  2020-06-21       28.0
# 21  2020-06-22        0.0
# 22  2020-06-23        0.0
# 23  2020-06-24        0.0
# 24  2020-06-25        0.0
# 25  2020-06-26        0.0
# 26  2020-06-27        0.0
# 27  2020-06-28       58.0
# 28  2020-06-29        0.0
# 29  2020-06-30        0.0

# %%
df_egypt = df[df['location'] == 'Egypt']
df_jan_egypt = df_egypt[['date', 'new_cases']][(df_egypt.date >= '2021-01-01') & (df_egypt.date <= '2021-01-31')].reset_index(drop=True)

# %%
df_jan_egypt.to_sql('df_jan_egypt',eng,index=False)
pd.read_sql('df_jan_egypt' ,eng)
# Out:
#           date  new_cases
# 0   2021-01-01        0.0
# 1   2021-01-02        0.0
# 2   2021-01-03     9563.0
# 3   2021-01-04        0.0
# 4   2021-01-05        0.0
# 5   2021-01-06        0.0
# 6   2021-01-07        0.0
# 7   2021-01-08        0.0
# 8   2021-01-09        0.0
# 9   2021-01-10     7921.0
# 10  2021-01-11        0.0
# 11  2021-01-12        0.0
# 12  2021-01-13        0.0
# 13  2021-01-14        0.0
# 14  2021-01-15        0.0
# 15  2021-01-16        0.0
# 16  2021-01-17     6708.0
# 17  2021-01-18        0.0
# 18  2021-01-19        0.0
# 19  2021-01-20        0.0
# 20  2021-01-21        0.0
# 21  2021-01-22        0.0
# 22  2021-01-23        0.0
# 23  2021-01-24     5636.0
# 24  2021-01-25        0.0
# 25  2021-01-26        0.0
# 26  2021-01-27        0.0
# 27  2021-01-28        0.0
# 28  2021-01-29        0.0
# 29  2021-01-30        0.0
# 30  2021-01-31     4275.0

# %%
###### maybe population_density
#Number of people divided by land area, measured in square kilometers, most recent year available
